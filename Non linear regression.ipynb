# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.arange(-5.0, 5.0, 0.1)
y = 2*x + 3
y_noise = 2*np.random.normal(size = x.size)
print(y_noise)
# Out:
# [-2.14798358e+00 -1.66763688e+00  1.69886819e+00  1.73271088e+00
#  -1.09800933e+00  1.87832357e+00  7.66596468e-01  2.00979413e+00
#  -1.05517202e+00 -3.14618641e+00  1.90226237e+00  5.71403887e-01
#   3.37728430e+00  2.92349954e+00  9.59462986e-01 -4.06794452e-01
#   4.21110701e+00  9.30377126e-01  2.18706739e-01 -3.84965610e+00
#  -1.34019351e+00 -1.47904275e+00  3.70589894e+00  2.37629661e+00
#  -2.04157594e-03 -4.16959154e+00 -1.55435588e+00  1.44214759e+00
#  -2.16100651e+00 -3.06167401e-03  5.08671013e-01  1.12169136e+00
#  -3.43466488e+00  5.76451173e+00  1.83715460e-01 -4.85781887e-01
#  -1.08355580e+00 -1.07836618e+00  4.55336735e+00 -5.20664302e-01
#  -3.67809496e-01  1.13547555e-03 -1.37008644e-01 -8.03008578e-02
#  -3.81533974e+00  2.95286712e+00  1.73060584e+00 -1.36215469e+00
#  -2.62126948e+00 -1.00368748e-01 -1.74488175e+00 -4.90918472e-01
#   2.58526821e+00 -4.91673645e+00 -1.41648300e+00 -2.52004936e-01
#  -1.13839097e+00 -2.20858469e+00  2.86386931e+00 -1.07474677e+00
#  -4.01952381e+00  1.53586204e+00 -3.71701688e-01  2.36267806e+00
#   7.43992308e-01 -1.05378494e-01 -2.37811827e+00 -3.53466428e+00
#   2.70715788e+00  1.96439252e+00  3.02398387e+00  3.73518637e+00
#   1.16961220e+00  3.33431355e+00 -1.71177913e+00 -9.50486985e-01
#   4.33681627e+00  9.44482294e-02 -2.67390122e+00  5.45726341e-01
#   3.70396194e+00 -9.15003959e-01 -1.94426653e+00  1.06364700e+00
#   8.62494707e-01 -5.23667338e+00 -8.07644864e-01  5.39826964e-01
#  -1.05684830e+00 -2.50526814e+00  1.56603535e+00  2.13122982e+00
#   2.29990618e+00 -4.63042060e+00 -3.18199414e-01  3.47199621e+00
#  -3.75640323e-01 -1.91173586e+00 -2.08930786e-01  4.41036383e-01]

# %%
y_data = y + y_noise
plt.plot(x, y_data, 'bo')
plt.plot(x,y,'r')
plt.ylabel('Dependent variable')
plt.xlabel('independent variable')
plt.show()

# %%
x = np.arange(-5.0, 5.0, 0.1)

##You can adjust the slope and intercept to verify the changes in the graph
y = 1*(x**3) + 1*(x**2) + 1*x + 3
y_noise = 10 * np.random.normal(size=x.size)
ydata = y + y_noise
plt.plot(x, ydata,  'bo')
plt.plot(x,y, 'r') 
plt.ylabel('Dependent Variable')
plt.xlabel('Indepdendent Variable')
plt.show()

# %%
x = np.arange(-5.0, 5.0, 0.1)

##You can adjust the slope and intercept to verify the changes in the graph

y = np.power(x,2)
y_noise = 1 * np.random.normal(size=x.size)
ydata = y + y_noise
plt.plot(x, ydata,  'bo')
plt.plot(x,y, 'r') 
plt.ylabel('Dependent Variable')
plt.xlabel('Indepdendent Variable')
plt.show()

# %%
x = np.arange(-5.0, 5.0, 0.1)
y = np.exp(x)
plt.plot(x,y)

# %%
x = np.arange(-5.0, 5.0, 0.1)

##You can adjust the slope and intercept to verify the changes in the graph

y = np.exp(x)
y_noise = 10 * np.random.normal(size=x.size)
ydata = y + y_noise
plt.plot(x, ydata,  'bo')
plt.plot(x,y, 'r') 
plt.ylabel('Dependent Variable')
plt.xlabel('Indepdendent Variable')
plt.show()

# %%
X = np.arange(-5.0, 5.0, 0.1)

Y = np.log(X)

plt.plot(X,Y) 
plt.ylabel('Dependent Variable')
plt.xlabel('Indepdendent Variable')
plt.show()
# Out:
# C:\Users\toqua\anaconda3\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
X = np.arange(-5.0, 5.0, 0.1)


Y = 1-4/(1+np.power(3, X-2))

plt.plot(X,Y) 
plt.ylabel('Dependent Variable')
plt.xlabel('Indepdendent Variable')
plt.show()

# %%
import numpy as np
import pandas as pd
df = pd.read_csv("china_gdp.csv")
df.head(10)
# Out:
#    Year         Value
# 0  1960  5.918412e+10
# 1  1961  4.955705e+10
# 2  1962  4.668518e+10
# 3  1963  5.009730e+10
# 4  1964  5.906225e+10
# 5  1965  6.970915e+10
# 6  1966  7.587943e+10
# 7  1967  7.205703e+10
# 8  1968  6.999350e+10
# 9  1969  7.871882e+10

# %%
plt.figure(figsize = (8,5))
x_data, y_data = (df['Year'].values, df['Value'].values)
plt.plot(x_data, y_data,'ro')
plt.ylabel('GPD')
plt.xlabel('year')
plt.show()

# %%
X = np.arange(-5.0, 5.0, 0.1)
Y = 1.0 / (1.0 + np.exp(-X))

plt.plot(X,Y) 
plt.ylabel('Dependent Variable')
plt.xlabel('Indepdendent Variable')
plt.show()

# %% [markdown]
# # fitting the logistic model

# %%
def sigmoid(x, Beta_1, Beta_2):
     y = 1 / (1 + np.exp(-Beta_1*(x-Beta_2)))
     return y

# %%
beta_1 = 0.10
beta_2 = 1990.0

#logistic function
Y_pred = sigmoid(x_data, beta_1 , beta_2)

#plot initial prediction against datapoints
plt.plot(x_data, Y_pred*15000000000000.)
plt.plot(x_data, y_data, 'ro')

# %%
# Lets normalize our data
xdata =x_data/max(x_data)
ydata =y_data/max(y_data)

# %%
from scipy.optimize import curve_fit
popt, pcov = curve_fit(sigmoid, xdata, ydata)
print(" beta_1 = %f, beta_2 = %f" % (popt[0], popt[1]))
# Out:
#  beta_1 = 690.451711, beta_2 = 0.997207

# %%
x = np.linspace(1960, 2015, 55)
x = x/max(x)
plt.figure(figsize=(8,5))
y = sigmoid(x, *popt)
plt.plot(xdata, ydata, 'ro', label='data')
plt.plot(x,y, linewidth=3.0, label='fit')
plt.legend(loc='best')
plt.ylabel('GDP')
plt.xlabel('Year')
plt.show()

# %%
msk = np.random.rand(len(df)) < 0.8
train_x = xdata[msk]
test_x = xdata[~msk]
train_y = ydata[msk]
test_y = ydata[~msk]

# %%
popt, pcov = curve_fit(sigmoid, train_x, train_y)
# Out:
# C:\Users\toqua\anaconda3\lib\site-packages\scipy\optimize\minpack.py:808: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)

# %%
y_hat = sigmoid(test_x, *popt)

# %%
print("Mean absolute error: %.2f" % np.mean(np.absolute(y_hat - test_y)))
print("Residual sum of squares (MSE): %.2f" % np.mean((y_hat - test_y) ** 2))
from sklearn.metrics import r2_score
print("R2-score: %.2f" % r2_score(y_hat , test_y) )
# Out:
# Mean absolute error: 0.30
# Residual sum of squares (MSE): 0.24
# R2-score: -2293822654129148023504932456890368.00
